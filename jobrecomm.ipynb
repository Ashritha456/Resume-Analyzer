# %%
# !pip install sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 59.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from google.colab import files
uploaded = files.upload()  # Upload 'job_title_des.csv' file
# Out:
#      <input type="file" id="files-78e7e146-b55e-44b9-bd1f-420ec3a2f29d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-78e7e146-b55e-44b9-bd1f-420ec3a2f29d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Load the CSV file
job_df = pd.read_csv('job_title_des.csv')

# Check the first few rows
job_df.head()
# Out:
#    Unnamed: 0             Job Title  \
# 0           0     Flutter Developer
# 1           1      Django Developer
# 2           2      Machine Learning
# 3           3         iOS Developer
# 4           4  Full Stack Developer
#
#                                      Job Description
# 0  We are looking for hire experts flutter develo...
# 1  PYTHON/DJANGO (Developer/Lead) - Job Code(PDJ ...
# 2  Data Scientist (Contractor)\n\nBangalore, IN\n...
# 3  JOB DESCRIPTION:\n\nStrong framework outside o...
# 4  job responsibility full stack engineer – react...

# %%
# Upload CSV file (if not already)
from google.colab import files
uploaded = files.upload()

# Load into pandas DataFrame
import pandas as pd
job_df = pd.read_csv('job_title_des.csv')

# Check the first few rows
job_df.head()
# Out:
#      <input type="file" id="files-e0965247-f027-41e6-8cd5-89bc91b2ed4f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e0965247-f027-41e6-8cd5-89bc91b2ed4f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from sentence_transformers import SentenceTransformer

# Load pre-trained sentence embedding model
embedder = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# ...

# %%
job_embeddings = embedder.encode(job_df['Job Description'].tolist(), convert_to_tensor=True)

# %%
def recommend_jobs(resume_text, job_df, job_embeddings, embedder, top_k=5):
    # Encode the resume
    resume_embedding = embedder.encode(resume_text, convert_to_tensor=True)

    # Calculate cosine similarities
    cosine_scores = torch.nn.functional.cosine_similarity(resume_embedding, job_embeddings)

    # Get top K results
    top_results = torch.topk(cosine_scores, k=top_k)

    recommendations = []
    for score, idx in zip(top_results.values, top_results.indices):
        job_title = job_df.iloc[idx.item()]['Job Title']   # 👈 Corrected
        job_description = job_df.iloc[idx.item()]['Job Description']   # 👈 Corrected
        recommendations.append((job_title, job_description, score.item()))

    return recommendations

# %%
# Example Resume Text
sample_resume = """
Experienced backend developer with expertise in Python, Django, Flask, and AWS cloud services.
"""

# Recommend top jobs
recommended_jobs = recommend_jobs(sample_resume, job_df, job_embeddings, embedder)

# Display recommendations
print("\nTop Recommended Jobs:\n")
for idx, (title, desc, score) in enumerate(recommended_jobs):
    print(f"{idx+1}. {title} (Score: {score:.4f})")
    print(f"   Description: {desc[:100]}...")
    print()
# Out:
# Top Recommended Jobs:
#
# 1. Django Developer (Score: 0.8224)
#    Description: Python
# Django
# Flask
# React.js
# Amazon Web Services (AWS)
# DevOps
# Linux/Unix
# Kubernetes
# Terraform
# Docker...
#
# 2. Django Developer (Score: 0.8009)
#    Description: We are looking for a Python (Django) Web Developer with 1+ years of experience to join our Engineeri...
#
# 3. Django Developer (Score: 0.7870)
#    Description: Experienced developer needed for maintaining a large enterprise application written in Python with D...
#
# 4. Django Developer (Score: 0.7852)
#    Description: Please find the Job Description below for backend developers (Python Django Web Application Develope...
#
# 5. Django Developer (Score: 0.7847)
#    Description: Role Description*
# We are looking for a Python (Django) Web Developer with 1+ years of experience to ...
